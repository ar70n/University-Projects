# %%
u = vector((500,1000))
M=Matrix([[0.8,0.2],[0.2,0.8]])

v= M^3*u

show(v)
# Out:
# (696.000000000000, 804.000000000000)

# %%
var('n')

M=Matrix([[1/3,1/2,0,0,0,2/3],[0,0,1/2,0,0,0],[0,1/2,0,1/2,0,0],[0,0,1/2,0,1/2,0],[0,0,0,1/2,0,0],[2/3,0,0,0,1/2,1/3]])
u = vector((3200/6,3200/6,3200/6,3200/6,3200/6,3200/6))
n=0
while u[0]+u[5]<=u[1]+u[2]+u[3]+u[4]:
    u=M*u
    n=n+1
show(u,n)
# Out:
# (2800/3, 800/3, 400, 400, 800/3, 2800/3) 2

# %%
M=Matrix(QQ,[[0.5,0,0.2],[0.5,0.75,0],[0,0.25,0.8]])
n=True
k=2
i=0
j=0
while n==True:
    n=False
    M=M^k
    for i in range(0,2):
        for j in range(0,2):
            if M[i][j]<=0:
                n = True
    k=k+1
print(k)
show(M)
# Out:
# 3
# [  1/4  1/20 13/50]
# [  5/8  9/16  1/10]
# [  1/8 31/80 16/25]

# %%
var('n')
u=vector(QQ,(1/3,1/3,1/3))
for n in range(0,1000):
    u=M^n*u
show(u)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_79/253755850.py in <module>
#       2 u=vector(QQ,(Integer(1)/Integer(3),Integer(1)/Integer(3),Integer(1)/Integer(3)))
#       3 for n in range(Integer(0),Integer(1000)):
# ----> 4     u=M**n*u
#       5 show(u)
#
# /usr/lib/python3/dist-packages/sage/structure/element.pyx in sage.structure.element.Matrix.__mul__ (build/cythonized/sage/structure/element.c:24069)()
#    3824
#    3825         if BOTH_ARE_ELEMENT(cl):
# -> 3826             return coercion_model.bin_op(left, right, mul)
#    3827
#    3828         cdef long value
#
# /usr/lib/python3/dist-packages/sage/structure/coerce.pyx in sage.structure.coerce.CoercionModel.bin_op (build/cythonized/sage/structure/coerce.c:10698)()
#    1192         if action is not None:
#    1193             if (<Action>action)._is_left:
# ...

# %%
M=Matrix(QQ,[[0.5,0,0.2],[0.5,0.75,0],[0,0.25,0.8]])
v1=(M-identity_matrix(QQ,M.nrows())).right_kernel().basis()[0] #[0] puesto que el método .basis() devuelve una lista
v1=v1/sum(v1)#v1 es un vector, se puede multiplicar por un escalar
print('El vector propio normalizado asociado al valor propio dominante es:')
print(v1)
# Out:
# El vector propio normalizado asociado al valor propio dominante es:
# (2/11, 4/11, 5/11)
