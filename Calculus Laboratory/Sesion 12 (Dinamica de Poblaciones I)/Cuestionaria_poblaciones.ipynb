# %%
L=Matrix([[1,3/2],[1/2,0]])

x_0=Matrix([[1024],[0]])

L^8*x_0
# Out:
# [19684]
# [ 6560]

# %%
L_1=Matrix(QQ,[[1,1,3],[1/2,0,0],[0,2/5,0]])
L_2=Matrix(QQ,[[0.,1,0],[2/5,0,0],[0,1/2,0]])
L_3=Matrix(QQ,[[1,3,1],[1/2,0,0],[0,2/5,0]])
L_4=Matrix(QQ,[[3,1,1],[1/2,0,0],[0,2/5,0]])

print(L_1.eigenvalues())
print(L_2.eigenvalues())
print(L_3.eigenvalues())
print(L_4.eigenvalues())

#4,3,1,2
# Out:
# [1.564646933753199?, -0.2823234668765996? - 0.5511502096532907?*I, -0.2823234668765996? + 0.5511502096532907?*I]
# [1, -0.25000000000000000? - 0.1936491673103709?*I, -0.25000000000000000? + 0.1936491673103709?*I]
# [-0.712077416062708?, -0.1507733931666498?, 1.862850809229358?]
# [3.177184786936650?, -0.08859239346832478? - 0.2347343122581106?*I, -0.08859239346832478? + 0.2347343122581106?*I]

# %%
var('h')
M=Matrix([[h,1,h],[2/5,0,0],[0,1/2,0]])

#print(M.eigenvalues())

for elem in M.eigenvalues():
    print(solve([elem==1],h))
# Out:
# [
# h == -(10^(2/3)*(10*h^3 + 45*h + 9*sqrt(20/3*h^4 + 59/3*h^2 - 32/15))^(1/3) + sqrt(-60*(10*h^3 + 45*h + 9*sqrt(20/3*h^4 + 59/3*h^2 - 32/15))^(1/3)*(-I*10^(2/3)*sqrt(3) + 10^(2/3)) - 30*10^(1/3)*(10*h^3 + 45*h + 9*sqrt(20/3*h^4 + 59/3*h^2 - 32/15))^(2/3) + 240*I*sqrt(3) + 240))/(10*I*sqrt(3) - 10),
# h == -(10^(2/3)*(10*h^3 + 45*h + 9*sqrt(20/3*h^4 + 59/3*h^2 - 32/15))^(1/3) - sqrt(-60*(10*h^3 + 45*h + 9*sqrt(20/3*h^4 + 59/3*h^2 - 32/15))^(1/3)*(-I*10^(2/3)*sqrt(3) + 10^(2/3)) - 30*10^(1/3)*(10*h^3 + 45*h + 9*sqrt(20/3*h^4 + 59/3*h^2 - 32/15))^(2/3) + 240*I*sqrt(3) + 240))/(10*I*sqrt(3) - 10)
# ]
# [
# h == (10^(2/3)*(10*h^3 + 45*h + 9*sqrt(20/3*h^4 + 59/3*h^2 - 32/15))^(1/3) - sqrt(-60*(10*h^3 + 45*h + 9*sqrt(20/3*h^4 + 59/3*h^2 - 32/15))^(1/3)*(I*10^(2/3)*sqrt(3) + 10^(2/3)) - 30*10^(1/3)*(10*h^3 + 45*h + 9*sqrt(20/3*h^4 + 59/3*h^2 - 32/15))^(2/3) - 240*I*sqrt(3) + 240))/(10*I*sqrt(3) + 10),
# ...

# %%
P=Matrix(QQ,[[0,0,1,3,1],[1/2,0,0,0,0],[0,4/5,0,0,0],[0,0,4/5,0,0],[0,0,0,4/5,0]])

# %%
P.eigenvectors_right()
# Out:
# [(-0.7513800798753380?,
#   [(1, -0.6654421821815603?, 0.7085012765224910?, -0.754346616844076?, 0.8031584941343987?)],
#   1),
#  (-0.3095540169885812?,
#   [(1, -1.615226979976306?, 4.174333114949403?, -10.78799275307970?, 27.88009112730111?)],
#   1),
#  (1.131446390023795?,
#   [(1, 0.4419122323502088?, 0.3124582737611918?, 0.2209266132385615?, 0.1562082765469182?)],
#   1),
#  (-0.03525614657993767? - 0.9856603469523477?*I,
#   [(1, -0.01812153509617137? + 0.5066259447754144?*I, -0.4101463326165432? - 0.02937868748441168?*I, 0.0357063783426054? - 0.3316134181467190?*I, 0.2677710510087893? + 0.03855859497222075?*I)],
#   1),
#  (-0.03525614657993767? + 0.9856603469523477?*I,
#   [(1, -0.01812153509617137? - 0.5066259447754144?*I, -0.4101463326165432? + 0.02937868748441168?*I, 0.0357063783426054? + 0.3316134181467190?*I, 0.2677710510087893? - 0.03855859497222075?*I)],
#   1)]
